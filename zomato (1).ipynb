# %%
import pandas as pd
import seaborn  as sns
import matplotlib.pyplot as plt
from datetime import datetime as dt
import warnings
df=pd.read_csv("C:\\Users\\Ayush\\Downloads\\zomato.csv")
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
dk=pd.read_excel("C:\\Users\\Ayush\\Downloads\\Zomato_Country-Code.xlsx")
dk.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
df.shape
# Out:
# (9551, 21)

# %%
dk.shape
# Out:
# (15, 2)

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
dk.isnull().sum()
# Out:
# Country Code    0
# Country         0
# dtype: int64

# %%
dk.dtypes
# Out:
# Country Code     int64
# Country         object
# dtype: object

# %%
df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
dk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Code  15 non-null     int64
#  1   Country       15 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 368.0+ bytes

# %%
for i in df.columns:
    print(i,'----------------',df[i].unique())
# Out:
# Restaurant ID ---------------- [6317637 6304287 6300002 ... 5915807 5916112 5927402]
# Restaurant Name ---------------- ['Le Petit Souffle' 'Izakaya Kikufuji' 'Heat - Edsa Shangri-La' ...
#  'Huqqa' 'A\x81ô\x81ôk Kahve' "Walter's Coffee Roastery"]
# Country Code ---------------- [162  30 216  14  37 184 214   1  94 148 215 166 189 191 208]
# City ---------------- ['Makati City' 'Mandaluyong City' 'Pasay City' 'Pasig City' 'Quezon City'
#  'San Juan City' 'Santa Rosa' 'Tagaytay City' 'Taguig City' 'Brasí_lia'
#  'Rio de Janeiro' 'Sí£o Paulo' 'Albany' 'Armidale' 'Athens' 'Augusta'
#  'Balingup' 'Beechworth' 'Boise' 'Cedar Rapids/Iowa City' 'Chatham-Kent'
#  'Clatskanie' 'Cochrane' 'Columbus' 'Consort' 'Dalton' 'Davenport'
#  'Des Moines' 'Dicky Beach' 'Dubuque' 'East Ballina' 'Fernley' 'Flaxton'
#  'Forrest' 'Gainesville' 'Hepburn Springs' 'Huskisson' 'Inverloch'
#  'Lakes Entrance' 'Lakeview' 'Lincoln' 'Lorn' 'Macedon' 'Macon' 'Mayfield'
# ...

# %%
df['Country Code'].unique()
# Out:
# array([162,  30, 216,  14,  37, 184, 214,   1,  94, 148, 215, 166, 189,
#        191, 208], dtype=int64)

# %%
dk['Country Code'].unique()
# Out:
# array([  1,  14,  30,  37,  94, 148, 162, 166, 184, 189, 191, 208, 214,
#        215, 216], dtype=int64)

# %%
df2=pd.merge(df,dk,how='left',on='Country Code')
df2
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
df['Cuisines']
# Out:
# 0             French, Japanese, Desserts
# 1                               Japanese
# 2       Seafood, Asian, Filipino, Indian
# 3                        Japanese, Sushi
# 4                       Japanese, Korean
#                       ...
# 9546                             Turkish
# 9547     World Cuisine, Patisserie, Cafe
# 9548              Italian, World Cuisine
# 9549                     Restaurant Cafe
# 9550                                Cafe
# Name: Cuisines, Length: 9551, dtype: object

# %%
df2['Cuisines'].isnull().sum()*100/df2.shape[0]
# Out:
# 0.09423097057899696

# %%
df2['Cuisines'].fillna(df2['Cuisines'].mode()[0],inplace=True)

# %%
df2.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
df2.duplicated().sum()
# Out:
# 0

# %%
df2['Country'].value_counts()
# Out:
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# UAE                 60
# South Africa        60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Qatar               20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64

# %%
plt.figure(figsize=(18,9))
plt.xticks(rotation=90)
sns.countplot(x='Country',data=df2)
# Out:
# <AxesSubplot:xlabel='Country', ylabel='count'>

# %%
# which country do  have online option
z=df2.groupby(['Country','Has Online delivery']).size().reset_index()
z
# Out:
#            Country Has Online delivery     0
# 0        Australia                  No    24
# 1           Brazil                  No    60
# 2           Canada                  No     4
# 3            India                  No  6229
# 4            India                 Yes  2423
# 5        Indonesia                  No    21
# 6      New Zealand                  No    40
# 7      Phillipines                  No    22
# 8            Qatar                  No    20
# 9        Singapore                  No    20
# 10    South Africa                  No    60
# 11       Sri Lanka                  No    20
# 12          Turkey                  No    34
# 13             UAE                  No    32
# 14             UAE                 Yes    28
# 15  United Kingdom                  No    80
# 16   United States                  No   434

# %%
# A

# %%
k=df2[df2['Country']=='India']
k
# Out:
#       Restaurant ID                        Restaurant Name  Country Code  \
# 624         3400025                             Jahanpanah             1
# 625         3400341                    Rangrezz Restaurant             1
# 626         3400005                Time2Eat - Mama Chicken             1
# 627         3400021  Chokho Jeeman Marwari Jain Bhojanalya             1
# 628         3400017                         Pinch Of Spice             1
# ...             ...                                    ...           ...
# 9271        2800100                               D Cabana             1
# 9272        2800418                               Kaloreez             1
# 9273        2800881                                Plot 17             1
# 9274        2800042                       Vista - The Park             1
# 9275        2800019               Flying Spaghetti Monster             1
#
#        City                                            Address  \
# ...

# %%
plt.figure(figsize=(18,9))
plt.xticks(rotation=90)
sns.countplot(k['City'],data=k);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df2=k['City'].value_counts().reset_index()
df2
# Out:
#            index  City
# 0      New Delhi  5473
# 1        Gurgaon  1118
# 2          Noida  1080
# 3      Faridabad   251
# 4      Ghaziabad    25
# 5      Ahmedabad    21
# 6       Guwahati    21
# 7        Lucknow    21
# 8   Bhubaneshwar    21
# 9       Amritsar    21
# 10          Pune    20
# 11    Puducherry    20
# 12         Patna    20
# 13      Ludhiana    20
# 14        Ranchi    20
# 15         Surat    20
# 16      Vadodara    20
# 17        Nashik    20
# 18        Nagpur    20
# 19        Mysore    20
# 20        Mumbai    20
# 21      Varanasi    20
# 22     Mangalore    20
# 23          Agra    20
# 24         Kochi    20
# 25       Kolkata    20
# 26      Dehradun    20
# 27     Allahabad    20
# 28    Aurangabad    20
# 29     Bangalore    20
# 30        Bhopal    20
# 31       Chennai    20
# 32    Coimbatore    20
# 33           Goa    20
# 34        Indore    20
# 35        Jaipur    20
# 36        Kanpur    20
# 37         Vizag    20
# 38    Chandigarh    18
# ...

# %%
# Eda of New Delhi

# %%
plt.figure(figsize=(18,9))
plt.xticks(rotation=90)
plt.pie(df2['City'],labels=df2['index'],autopct="%0.02f%%");
plt.legend()

# %%
df2.iloc[5:,0]='other'

# %%
df2
# Out:
#         index  City
# 0   New Delhi  5473
# 1     Gurgaon  1118
# 2       Noida  1080
# 3   Faridabad   251
# 4   Ghaziabad    25
# 5       other    21
# 6       other    21
# 7       other    21
# 8       other    21
# 9       other    21
# 10      other    20
# 11      other    20
# 12      other    20
# 13      other    20
# 14      other    20
# 15      other    20
# 16      other    20
# 17      other    20
# 18      other    20
# 19      other    20
# 20      other    20
# 21      other    20
# 22      other    20
# 23      other    20
# 24      other    20
# 25      other    20
# 26      other    20
# 27      other    20
# 28      other    20
# 29      other    20
# 30      other    20
# 31      other    20
# 32      other    20
# 33      other    20
# 34      other    20
# 35      other    20
# 36      other    20
# 37      other    20
# 38      other    18
# 39      other    18
# 40      other     2
# 41      other     1
# 42      other     1

# %%
k2=df2.groupby('index')['City'].sum().reset_index()
k2
# Out:
#        index  City
# 0  Faridabad   251
# 1  Ghaziabad    25
# 2    Gurgaon  1118
# 3  New Delhi  5473
# 4      Noida  1080
# 5      other   705

# %%
plt.pie(k2['City'],explode=[1,2,0,0,0,0],labels=k2['index'],autopct="%0.02f%%");

# %%
k.describe().T
# Out:
#                        count          mean           std   min            25%  \
# Restaurant ID         8652.0  8.657085e+06  8.959437e+06  53.0  300740.250000
# Country Code          8652.0  1.000000e+00  0.000000e+00   1.0       1.000000
# Longitude             8652.0  7.285679e+01  1.801754e+01   0.0      77.098797
# Latitude              8652.0  2.642065e+01  6.976576e+00   0.0      28.491425
# Average Cost for two  8652.0  6.233703e+02  5.956761e+02   0.0     300.000000
# Price range           8652.0  1.721683e+00  8.525437e-01   1.0       1.000000
# Aggregate rating      8652.0  2.523324e+00  1.510986e+00   0.0       2.100000
# Votes                 8652.0  1.372126e+02  4.280395e+02   0.0       4.000000
#
#                                50%           75%           max
# Restaurant ID         2.200006e+06  1.836120e+07  1.850065e+07
# Country Code          1.000000e+00  1.000000e+00  1.000000e+00
# Longitude             7.720347e+01  7.728536e+01  9.180649e+01
# ...

# %%
x1=k['Cuisines'].value_counts().reset_index()
x1
# Out:
#                                                   index  Cuisines
# 0                                          North Indian       936
# 1                                 North Indian, Chinese       511
# 2                                             Fast Food       348
# 3                                               Chinese       340
# 4                                 North Indian, Mughlai       334
# ...                                                 ...       ...
# 1387  Chinese, Japanese, Thai, Malaysian, Vietnamese...         1
# 1388                 North Indian, Street Food, Mughlai         1
# 1389    Seafood, South Indian, Andhra, Hyderabadi, Goan         1
# 1390     Chinese, Fast Food, North Indian, South Indian         1
# 1391          American, North Indian, Thai, Continental         1
#
# [1392 rows x 2 columns]

# %%
# which restuarant is expensive based on cusin type of each city

# %%
x2=k[k['Average Cost for two']!=0]
x2
# Out:
#       Restaurant ID                        Restaurant Name  Country Code  \
# 624         3400025                             Jahanpanah             1
# 625         3400341                    Rangrezz Restaurant             1
# 626         3400005                Time2Eat - Mama Chicken             1
# 627         3400021  Chokho Jeeman Marwari Jain Bhojanalya             1
# 628         3400017                         Pinch Of Spice             1
# ...             ...                                    ...           ...
# 9271        2800100                               D Cabana             1
# 9272        2800418                               Kaloreez             1
# 9273        2800881                                Plot 17             1
# 9274        2800042                       Vista - The Park             1
# 9275        2800019               Flying Spaghetti Monster             1
#
#        City                                            Address  \
# ...

# %%
k2=x2.groupby(['City','Cuisines'])['Average Cost for two'].mean().reset_index().sort_values(by=['City','Average Cost for two'])
k2.head(13)
# Out:
#     City                                     Cuisines  Average Cost for two
# 10  Agra                                   Rajasthani                 400.0
# 3   Agra                                 North Indian                 500.0
# 12  Agra                       South Indian, Desserts                 550.0
# 1   Agra                               Italian, Pizza                 700.0
# 8   Agra                      North Indian, Fast Food                 700.0
# 11  Agra                Rajasthani, Gujarati, Mughlai                 800.0
# 0   Agra  Chinese, Italian, Continental, North Indian                1000.0
# 6   Agra               North Indian, Chinese, Mughlai                1000.0
# 5   Agra  North Indian, Chinese, Continental, Mughlai                1100.0
# 4   Agra           North Indian, Chinese, Continental                1500.0
# 9   Agra                        North Indian, Mughlai                1710.0
# ...

# %%
# how many resuarant of each cusin in city
k.groupby('City')['Cuisines'].value_counts()
# Out:
# City   Cuisines
# Agra   North Indian, Mughlai                                        5
#        North Indian, Chinese, Continental                           2
#        Cafe, Italian, Mexican, North Indian, Continental            1
#        Cafe, North Indian, Chinese                                  1
#        Chinese, Italian, Continental, North Indian                  1
#                                                                    ..
# Vizag  Mughlai, Chinese, Cafe, BBQ, Cajun                           1
#        North Indian, Biryani                                        1
#        North Indian, Chinese, Mediterranean                         1
#        South Indian, Chinese, Continental, Italian, North Indian    1
#        South Indian, North Indian                                   1
# Name: Cuisines, Length: 2220, dtype: int64

# %%
# which type resuarnt have higest and  least rating in city

# %%
k.groupby(['City','Cuisines'])['Aggregate rating'].mean().reset_index().sort_values(by=['City','Aggregate rating'])
k.head(10)
# Out:
#      Restaurant ID                        Restaurant Name  Country Code  City  \
# 624        3400025                             Jahanpanah             1  Agra
# 625        3400341                    Rangrezz Restaurant             1  Agra
# 626        3400005                Time2Eat - Mama Chicken             1  Agra
# 627        3400021  Chokho Jeeman Marwari Jain Bhojanalya             1  Agra
# 628        3400017                         Pinch Of Spice             1  Agra
# 629        3400325                              MoMo Cafe             1  Agra
# 630        3400059                  Peshawri - ITC Mughal             1  Agra
# 631        3400060                  Taj Bano - ITC Mughal             1  Agra
# 632        3400348                                 G Thal             1  Agra
# 633        3400072           Dawat-e-Nawab - Radisson Blu             1  Agra
#
#                                                Address  \
# ...

# %% [markdown]
# type(123) int
# type(19/12/2022) object
# type(20-12-2023) object

# %%
# whts is the max min rating  of retuarant

# %%
df['Aggregate rating'].agg(['min','max','mean'])
# Out:
# min     0.00000
# max     4.90000
# mean    2.66637
# Name: Aggregate rating, dtype: float64

# %%
ratings=k.groupby(['Aggregate rating','Rating color','Rating text']).size().reset_index().rename(columns={0:'Rating Count'})
ratings
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated          2139
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            26
# 6                2.3          Red        Poor            46
# 7                2.4          Red        Poor            83
# 8                2.5       Orange     Average           109
# 9                2.6       Orange     Average           190
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           314
# 12               2.9       Orange     Average           380
# 13               3.0       Orange     Average           465
# 14               3.1       Orange     Average           511
# ...

# %%
plt.figure(figsize=(18,9))
plt.xticks(rotation=90)
sns.barplot(ratings['Aggregate rating'],ratings['Rating Count'],hue='Rating text',data=ratings);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(x="Rating color",data=ratings,palette=["black","red","orange","yellow","green","green"]);

# %%
k2=k.groupby(["City","Restaurant Name","Aggregate rating"])["Votes"].mean().reset_index()
k2.rename(columns={"mean":"votes"},inplace=True)

# %%
k2[k2["City"]=="New Delhi"].sort_values(by="Aggregate rating",ascending=False)
# Out:
#            City            Restaurant Name  Aggregate rating   Votes
# 4007  New Delhi  Indian Accent - The Manor               4.9  1934.0
# 4626  New Delhi             Masala Library               4.9   408.0
# 4918  New Delhi         Naturals Ice Cream               4.9  2620.0
# 4333  New Delhi               Kopper Kadai               4.8    83.0
# 4519  New Delhi                MOB Brewpub               4.7    52.0
# ...         ...                        ...               ...     ...
# 3520  New Delhi              Food En Vouge               0.0     0.0
# 3519  New Delhi                 Food Daddy               0.0     1.0
# 6028  New Delhi            Sonu Bhojanalya               0.0     2.0
# 6027  New Delhi            Soni Food Court               0.0     0.0
# 1884  New Delhi               #InstaFreeze               0.0     2.0
#
# [5042 rows x 4 columns]

# %%
k(k['City']=='New Delhi')&(k['Aggregate rating']=4.9)
# Out:
#   Input In [56]
#     k(k['City']=='New Delhi')&(k['Aggregate rating']=4.9)
#                                                     ^
# SyntaxError: invalid syntax

# %%
k1=k[k['Aggregate rating']==0.0]
k1.groupby(['City'])['Rating text'].value_counts()
# Out:
# City       Rating text
# Faridabad  Not rated       100
# Ghaziabad  Not rated         2
# Gurgaon    Not rated       228
# New Delhi  Not rated      1425
# Noida      Not rated       384
# Name: Rating text, dtype: int64

# %%
print("the number of restaurants which gives online delivery  and proir table booking option----",len(k[(k["Has Online delivery"]=="Yes") & (k["Has Table booking"]=="Yes")]))
print("the number of restaurants which gives only online delivery  and no proir table booking option----",len(k[(k["Has Online delivery"]=="Yes") & (k["Has Table booking"]=="No")]))
print("the number of restaurants which gives only proir table booking option and no online delievery----",len(k[(k["Has Online delivery"]=="No") & (k["Has Table booking"]=="Yes")]))
print("the number of restaurants which gives neither option ----",len(k[(k["Has Online delivery"]=="No") & (k["Has Table booking"]=="No")]))
# Out:
# the number of restaurants which gives online delivery  and proir table booking option---- 427
# the number of restaurants which gives only online delivery  and no proir table booking option---- 1996
# the number of restaurants which gives only proir table booking option and no online delievery---- 684
# the number of restaurants which gives neither option ---- 5545

# %%
File sentences.csv contains 15 sentences, highlighting different mood of an individual. These moods are classified into two categories depressed and casual, based on the words listed below, depressed=[rejects, bullied, lonely, dead, wrong] casual = [excited, happy, party, good] Use this list to add label column as Condition either depressed or normal.
